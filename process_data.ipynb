# %%
# this NOTEBOOK has the connection to S3 to read and write

# %%
# Import packages for data manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import packages for data modeling
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance

# This lets us see all of the columns, preventing Juptyer from redacting them.
pd.set_option('display.max_columns', None)

# This module lets us save our models once we fit them.
import pickle

# %% [markdown]
# ## Data Connection To S3

# %%
#Import packages for data connection to S3
import boto3
from io import StringIO

# %%
# AWS credentials
#aws_access_key_id = '' #ask prescila for values here .. DO NOT UPLOAD TO GIT with values here
#aws_secret_access_key = '' #ask prescila for values here.. DO NOT UPLOAD TO GIT with values here
#bucket_name = '' #ask prescila for values here.. DO NOT UPLOAD TO GIT with values here


# Path to local CSV file
file_path = 'C:/churn/bucketcredentials.csv'
credentials_df = pd.read_csv(file_path)

aws_access_key_id = credentials_df['aws_access_key_id'].iloc[0]
aws_secret_access_key = credentials_df['aws_secret_access_key'].iloc[0]
bucket_name = credentials_df['bucket_name'].iloc[0]

input_file_key = 'SourceDataSet/bank_data_train.csv'
output_file_key = 'TargetDataSet/clean_bankchurn.csv'

# %%
# Create an S3 client
s3_client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

# %%
# Read the CSV file from S3 into a DataFrame
obj = s3_client.get_object(Bucket=bucket_name, Key=input_file_key)
df = pd.read_csv(obj['Body'])

# %%
# Read in the data in local machine
#df = pd.read_csv('bank_data_train.csv')
# This is replaced using S3 bucket

# %%
df.head(2)
# Out:
#        ID  CR_PROD_CNT_IL  AMOUNT_RUB_CLO_PRC  PRC_ACCEPTS_A_EMAIL_LINK  \
# 0  146841               0            0.000000                       NaN
# 1  146842               0            0.041033                       NaN
#
#    APP_REGISTR_RGN_CODE  PRC_ACCEPTS_A_POS  PRC_ACCEPTS_A_TK  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
#
#    TURNOVER_DYNAMIC_IL_1M  CNT_TRAN_AUT_TENDENCY1M  SUM_TRAN_AUT_TENDENCY1M  \
# 0                     0.0                      NaN                      NaN
# 1                     0.0                 0.166667                 0.186107
#
#    AMOUNT_RUB_SUP_PRC  PRC_ACCEPTS_A_AMOBILE  SUM_TRAN_AUT_TENDENCY3M  \
# 0            0.000000                    NaN                      NaN
# 1            0.244678                    NaN                 0.670968
#
#   CLNT_TRUST_RELATION  PRC_ACCEPTS_TK  PRC_ACCEPTS_A_MTP  \
# 0                 NaN             NaN                NaN
# 1                 NaN             NaN                NaN
#
#    REST_DYNAMIC_FDEP_1M  CNT_TRAN_AUT_TENDENCY3M  CNT_ACCEPTS_TK  \
# 0                   0.0                      NaN             NaN
# 1                   0.0                 0.666667             NaN
#
#   APP_MARITAL_STATUS  REST_DYNAMIC_SAVE_3M  CR_PROD_CNT_VCU   REST_AVG_CUR  \
# 0                NaN              0.541683                0  156067.339800
# 1                NaN              0.000000                0    4278.845817
#
#    CNT_TRAN_MED_TENDENCY1M APP_KIND_OF_PROP_HABITATION CLNT_JOB_POSITION_TYPE  \
# 0                      NaN                         NaN                    NaN
# 1                      NaN                         NaN                    NaN
#
#    AMOUNT_RUB_NAS_PRC CLNT_JOB_POSITION APP_DRIVING_LICENSE  \
# 0                 0.0  начальник отдела                 NaN
# 1                 0.0               NaN                 NaN
#
#    TRANS_COUNT_SUP_PRC APP_EDUCATION  CNT_TRAN_CLO_TENDENCY1M  \
# 0             0.000000           NaN                      NaN
# 1             0.454545           NaN                      NaN
#
#    SUM_TRAN_MED_TENDENCY1M  PRC_ACCEPTS_A_ATM  PRC_ACCEPTS_MTP  \
# 0                      NaN                NaN              NaN
# 1                      NaN                NaN              NaN
#
#    TRANS_COUNT_NAS_PRC APP_TRAVEL_PASS  CNT_ACCEPTS_MTP  CR_PROD_CNT_TOVR  \
# 0                  0.0             NaN              NaN                 0
# 1                  0.0             NaN              NaN                 0
#
#   APP_CAR  CR_PROD_CNT_PIL  SUM_TRAN_CLO_TENDENCY1M APP_POSITION_TYPE  \
# 0     NaN                0                      NaN               NaN
# 1     NaN                0                      NaN               NaN
#
#    TURNOVER_CC  TRANS_COUNT_ATM_PRC  AMOUNT_RUB_ATM_PRC  TURNOVER_PAYM  AGE  \
# 0          0.0             1.000000            1.000000            0.0  660
# 1          0.0             0.109091            0.410691            0.0  552
#
#    CNT_TRAN_MED_TENDENCY3M  CR_PROD_CNT_CC  SUM_TRAN_MED_TENDENCY3M  \
# 0                      NaN               0                      NaN
# 1                      NaN               0                      NaN
#
#    REST_DYNAMIC_FDEP_3M  REST_DYNAMIC_IL_1M APP_EMP_TYPE  \
# 0                   0.0                 0.0          NaN
# 1                   0.0                 0.0          NaN
#
#    SUM_TRAN_CLO_TENDENCY3M  LDEAL_TENOR_MAX  LDEAL_YQZ_CHRG  CR_PROD_CNT_CCFP  \
# 0                      NaN              NaN             NaN                 0
# 1                      NaN              NaN             NaN                 0
#
#    DEAL_YQZ_IR_MAX  LDEAL_YQZ_COM  DEAL_YQZ_IR_MIN  CNT_TRAN_CLO_TENDENCY3M  \
# 0              NaN            NaN              NaN                      NaN
# 1              NaN            NaN              NaN                      NaN
#
#    REST_DYNAMIC_CUR_1M  REST_AVG_PAYM  LDEAL_TENOR_MIN  LDEAL_AMT_MONTH  \
# 0             0.134651            0.0              NaN              NaN
# 1             0.239365            0.0              NaN              NaN
#
#   APP_COMP_TYPE  LDEAL_GRACE_DAYS_PCT_MED  REST_DYNAMIC_CUR_3M  \
# 0           NaN                       0.0             0.474134
# 1           NaN                       0.0             0.384264
#
#    CNT_TRAN_SUP_TENDENCY3M  TURNOVER_DYNAMIC_CUR_1M  REST_DYNAMIC_PAYM_3M  \
# 0                      NaN                 0.131910                   0.0
# 1                      0.6                 0.101934                   0.0
#
#    SUM_TRAN_SUP_TENDENCY3M  REST_DYNAMIC_IL_3M  CNT_TRAN_ATM_TENDENCY3M  \
# 0                      NaN                 0.0                 0.406780
# 1                 0.510712                 0.0                 0.333333
#
#    CNT_TRAN_ATM_TENDENCY1M  TURNOVER_DYNAMIC_IL_3M  SUM_TRAN_ATM_TENDENCY3M  \
# 0                 0.101695                     0.0                 0.483032
# 1                 0.166667                     0.0                 0.200000
#
#    DEAL_GRACE_DAYS_ACC_S1X1  AVG_PCT_MONTH_TO_PCLOSE  DEAL_YWZ_IR_MIN  \
# 0                       NaN                      NaN              NaN
# 1                       NaN                      NaN              NaN
#
#    SUM_TRAN_SUP_TENDENCY1M  DEAL_YWZ_IR_MAX  SUM_TRAN_ATM_TENDENCY1M  \
# 0                      NaN              NaN                 0.134634
# 1                 0.309799              NaN                 0.133333
#
#    REST_DYNAMIC_PAYM_1M  CNT_TRAN_SUP_TENDENCY1M  DEAL_GRACE_DAYS_ACC_AVG  \
# 0                   0.0                      NaN                      NaN
# 1                   0.0                     0.24                      NaN
#
#    TURNOVER_DYNAMIC_CUR_3M PACK  MAX_PCLOSE_DATE  LDEAL_YQZ_PC  \
# 0                 0.442285  K01              NaN           NaN
# 1                 0.515876  102              NaN           NaN
#
#    CLNT_SETUP_TENOR  DEAL_GRACE_DAYS_ACC_MAX  TURNOVER_DYNAMIC_PAYM_3M  \
# 0          1.593023                      NaN                       0.0
# 1          1.587647                      NaN                       0.0
#
#    LDEAL_DELINQ_PER_MAXYQZ  TURNOVER_DYNAMIC_PAYM_1M  CLNT_SALARY_VALUE  \
# 0                      NaN                       0.0                NaN
# 1                      NaN                       0.0                NaN
#
#    TRANS_AMOUNT_TENDENCY3M  MED_DEBT_PRC_YQZ  TRANS_CNT_TENDENCY3M  \
# 0                 0.483032               NaN              0.406780
# 1                 0.394340               NaN              0.545455
#
#    LDEAL_USED_AMT_AVG_YQZ  REST_DYNAMIC_CC_1M  LDEAL_USED_AMT_AVG_YWZ  \
# 0                     NaN                 0.0                     NaN
# 1                     NaN                 0.0                     NaN
#
#    TURNOVER_DYNAMIC_CC_1M  AVG_PCT_DEBT_TO_DEAL_AMT  \
# 0                     0.0                       NaN
# 1                     0.0                       NaN
#
#    LDEAL_ACT_DAYS_ACC_PCT_AVG  REST_DYNAMIC_CC_3M  MED_DEBT_PRC_YWZ  \
# 0                         NaN                 0.0               NaN
# 1                         NaN                 0.0               NaN
#
#    LDEAL_ACT_DAYS_PCT_TR3  LDEAL_ACT_DAYS_PCT_AAVG  LDEAL_DELINQ_PER_MAXYWZ  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
#
#    TURNOVER_DYNAMIC_CC_3M  LDEAL_ACT_DAYS_PCT_TR  LDEAL_ACT_DAYS_PCT_TR4  \
# 0                     0.0                    NaN                     NaN
# 1                     0.0                    NaN                     NaN
#
#    LDEAL_ACT_DAYS_PCT_CURR  TARGET
# 0                      NaN       0
# 1                      NaN       0

# %% [markdown]
# ## Data cleaning and pre-processing

# %% [markdown]
# ### 1. Changing to lowercase column names to improve readability.

# %%
# Loop through each column name
for col in df.columns:
  # Check if the column name is uppercase
  if col.isupper():
    # Rename the column to lowercase
    df.rename(columns={col: col.lower()}, inplace=True)

df.columns
# Out:
# Index(['id', 'cr_prod_cnt_il', 'amount_rub_clo_prc',
#        'prc_accepts_a_email_link', 'app_registr_rgn_code', 'prc_accepts_a_pos',
#        'prc_accepts_a_tk', 'turnover_dynamic_il_1m', 'cnt_tran_aut_tendency1m',
#        'sum_tran_aut_tendency1m',
#        ...
#        'rest_dynamic_cc_3m', 'med_debt_prc_ywz', 'ldeal_act_days_pct_tr3',
#        'ldeal_act_days_pct_aavg', 'ldeal_delinq_per_maxywz',
#        'turnover_dynamic_cc_3m', 'ldeal_act_days_pct_tr',
#        'ldeal_act_days_pct_tr4', 'ldeal_act_days_pct_curr', 'target'],
#       dtype='object', length=116)

# %% [markdown]
# >Using describe function to understand better the data

# %%
df.describe(include='all')
# Out:
#                    id  cr_prod_cnt_il  amount_rub_clo_prc  \
# count   355190.000000   355190.000000       316867.000000
# unique            NaN             NaN                 NaN
# top               NaN             NaN                 NaN
# freq              NaN             NaN                 NaN
# mean    368794.674875        0.105225            0.044045
# std     128148.804566        0.431372            0.108449
# min     146841.000000        0.000000            0.000000
# 25%     257846.250000        0.000000            0.000000
# 50%     368778.500000        0.000000            0.000000
# 75%     479737.750000        0.000000            0.036608
# max     590828.000000       11.000000            1.000000
#
#         prc_accepts_a_email_link  app_registr_rgn_code  prc_accepts_a_pos  \
# count                   155163.0          60550.000000           155163.0
# unique                       NaN                   NaN                NaN
# top                          NaN                   NaN                NaN
# freq                         NaN                   NaN                NaN
# mean                         0.0             50.947498                0.0
# std                          0.0             21.777855                0.0
# min                          0.0              0.000000                0.0
# 25%                          0.0             33.000000                0.0
# 50%                          0.0             54.000000                0.0
# 75%                          0.0             72.000000                0.0
# max                          0.0             89.000000                0.0
#
#         prc_accepts_a_tk  turnover_dynamic_il_1m  cnt_tran_aut_tendency1m  \
# count           155163.0           355190.000000             77112.000000
# unique               NaN                     NaN                      NaN
# top                  NaN                     NaN                      NaN
# freq                 NaN                     NaN                      NaN
# mean                 0.0                0.001305                 0.416896
# std                  0.0                0.029118                 0.316493
# min                  0.0                0.000000                 0.006944
# 25%                  0.0                0.000000                 0.166667
# 50%                  0.0                0.000000                 0.300000
# 75%                  0.0                0.000000                 0.571429
# max                  0.0                1.000000                 1.000000
#
#         sum_tran_aut_tendency1m  amount_rub_sup_prc  prc_accepts_a_amobile  \
# count              77112.000000       316867.000000               155163.0
# unique                      NaN                 NaN                    NaN
# top                         NaN                 NaN                    NaN
# freq                        NaN                 NaN                    NaN
# mean                   0.414572            0.085249                    0.0
# std                    0.338612            0.142310                    0.0
# min                    0.000000            0.000000                    0.0
# 25%                    0.139645            0.000000                    0.0
# 50%                    0.285714            0.027117                    0.0
# 75%                    0.661195            0.110005                    0.0
# max                    1.000000            1.000000                    0.0
#
#         sum_tran_aut_tendency3m clnt_trust_relation  prc_accepts_tk  \
# count             111052.000000               69421        155163.0
# unique                      NaN                  21             NaN
# top                         NaN              FRIEND             NaN
# freq                        NaN               24896             NaN
# mean                   0.689080                 NaN             0.0
# std                    0.301725                 NaN             0.0
# min                    0.000002                 NaN             0.0
# 25%                    0.446269                 NaN             0.0
# 50%                    0.722985                 NaN             0.0
# 75%                    1.000000                 NaN             0.0
# max                    1.000000                 NaN             0.0
#
#         prc_accepts_a_mtp  rest_dynamic_fdep_1m  cnt_tran_aut_tendency3m  \
# count            155163.0         355190.000000            111052.000000
# unique                NaN                   NaN                      NaN
# top                   NaN                   NaN                      NaN
# freq                  NaN                   NaN                      NaN
# mean                  0.0              0.000723                 0.691702
# std                   0.0              0.014081                 0.276582
# min                   0.0              0.000000                 0.008000
# 25%                   0.0              0.000000                 0.500000
# 50%                   0.0              0.000000                 0.666667
# 75%                   0.0              0.000000                 1.000000
# max                   0.0              1.000000                 1.000000
#
#         cnt_accepts_tk app_marital_status  rest_dynamic_save_3m  \
# count         155163.0              68234         355190.000000
# unique             NaN                 13                   NaN
# top                NaN                  M                   NaN
# freq               NaN              30724                   NaN
# mean               0.0                NaN              0.063400
# std                0.0                NaN              0.202963
# min                0.0                NaN              0.000000
# 25%                0.0                NaN              0.000000
# 50%                0.0                NaN              0.000000
# 75%                0.0                NaN              0.000000
# max                0.0                NaN              1.000000
#
#         cr_prod_cnt_vcu  rest_avg_cur  cnt_tran_med_tendency1m  \
# count     355190.000000  3.551900e+05             68967.000000
# unique              NaN           NaN                      NaN
# top                 NaN           NaN                      NaN
# freq                NaN           NaN                      NaN
# mean           0.031214  6.635854e+04                 0.443912
# std            0.184059  1.878598e+05                 0.323898
# min            0.000000  0.000000e+00                 0.010309
# 25%            0.000000  4.070440e+03                 0.181818
# 50%            0.000000  1.628925e+04                 0.333333
# 75%            0.000000  5.659516e+04                 0.666667
# max            4.000000  2.202141e+07                 1.000000
#
#        app_kind_of_prop_habitation clnt_job_position_type  amount_rub_nas_prc  \
# count                        59361                  44781       316867.000000
# unique                           5                      4                 NaN
# top                             SO             SPECIALIST                 NaN
# freq                         28056                  25123                 NaN
# mean                           NaN                    NaN            0.023971
# std                            NaN                    NaN            0.090774
# min                            NaN                    NaN            0.000000
# 25%                            NaN                    NaN            0.000000
# 50%                            NaN                    NaN            0.000000
# 75%                            NaN                    NaN            0.010536
# max                            NaN                    NaN            1.000000
#
#        clnt_job_position app_driving_license  trans_count_sup_prc  \
# count             210811               57257        316867.000000
# unique             19552                   2                  NaN
# top             ДИРЕКТОР                   N                  NaN
# freq               11200               36332                  NaN
# mean                 NaN                 NaN             0.191057
# std                  NaN                 NaN             0.195820
# min                  NaN                 NaN             0.000000
# 25%                  NaN                 NaN             0.000000
# 50%                  NaN                 NaN             0.147059
# 75%                  NaN                 NaN             0.310345
# max                  NaN                 NaN             1.000000
#
#        app_education  cnt_tran_clo_tendency1m  sum_tran_med_tendency1m  \
# count          68104             66296.000000             68967.000000
# unique            17                      NaN                      NaN
# top                H                      NaN                      NaN
# freq           42459                      NaN                      NaN
# mean             NaN                 0.479829                 0.437471
# std              NaN                 0.330155                 0.361986
# min              NaN                 0.010417                 0.000000
# 25%              NaN                 0.200000                 0.118692
# 50%              NaN                 0.363636                 0.310170
# 75%              NaN                 0.750000                 0.803627
# max              NaN                 1.000000                 1.000000
#
#         prc_accepts_a_atm  prc_accepts_mtp  trans_count_nas_prc  \
# count            155163.0         155163.0        316867.000000
# unique                NaN              NaN                  NaN
# top                   NaN              NaN                  NaN
# freq                  NaN              NaN                  NaN
# mean                  0.0              0.0             0.050886
# std                   0.0              0.0             0.116497
# min                   0.0              0.0             0.000000
# 25%                   0.0              0.0             0.000000
# 50%                   0.0              0.0             0.000000
# 75%                   0.0              0.0             0.048276
# max                   0.0              0.0             1.000000
#
#        app_travel_pass  cnt_accepts_mtp  cr_prod_cnt_tovr app_car  \
# count            57257         155163.0     355190.000000   57256
# unique               2              NaN               NaN       2
# top                  N              NaN               NaN       N
# freq             52750              NaN               NaN   32843
# mean               NaN              0.0          0.309930     NaN
# std                NaN              0.0          0.588759     NaN
# min                NaN              0.0          0.000000     NaN
# 25%                NaN              0.0          0.000000     NaN
# 50%                NaN              0.0          0.000000     NaN
# 75%                NaN              0.0          1.000000     NaN
# max                NaN              0.0         13.000000     NaN
#
#         cr_prod_cnt_pil  sum_tran_clo_tendency1m app_position_type  \
# count     355190.000000             6.629600e+04             60545
# unique              NaN                      NaN                 4
# top                 NaN                      NaN        SPECIALIST
# freq                NaN                      NaN             36622
# mean           0.056863             4.729494e-01               NaN
# std            0.296068             3.614758e-01               NaN
# min            0.000000             8.040000e-07               NaN
# 25%            0.000000             1.478078e-01               NaN
# 50%            0.000000             3.633948e-01               NaN
# 75%            0.000000             8.973466e-01               NaN
# max            9.000000             1.000000e+00               NaN
#
#          turnover_cc  trans_count_atm_prc  amount_rub_atm_prc  turnover_paym  \
# count   3.551900e+05        316867.000000       316867.000000   3.551900e+05
# unique           NaN                  NaN                 NaN            NaN
# top              NaN                  NaN                 NaN            NaN
# freq             NaN                  NaN                 NaN            NaN
# mean    4.963772e+02             0.370588            0.598252   1.446766e+04
# std     1.234083e+04             0.343410            0.363546   1.459378e+05
# min     0.000000e+00             0.000000            0.000000   0.000000e+00
# 25%     0.000000e+00             0.083916            0.268672   0.000000e+00
# 50%     0.000000e+00             0.250000            0.689935   0.000000e+00
# 75%     0.000000e+00             0.615385            0.954526   0.000000e+00
# max     3.753042e+06             1.000000            1.000000   4.628044e+07
#
#                   age  cnt_tran_med_tendency3m  cr_prod_cnt_cc  \
# count   355190.000000            115877.000000   355190.000000
# unique            NaN                      NaN             NaN
# top               NaN                      NaN             NaN
# freq              NaN                      NaN             NaN
# mean       457.148073                 0.700676        0.071531
# std        136.435457                 0.281790        0.294748
# min        168.000000                 0.032258        0.000000
# 25%        348.000000                 0.500000        0.000000
# 50%        432.000000                 0.692308        0.000000
# 75%        552.000000                 1.000000        0.000000
# max       1128.000000                 1.000000        9.000000
#
#         sum_tran_med_tendency3m  rest_dynamic_fdep_3m  rest_dynamic_il_1m  \
# count             115877.000000         355190.000000       355190.000000
# unique                      NaN                   NaN                 NaN
# top                         NaN                   NaN                 NaN
# freq                        NaN                   NaN                 NaN
# mean                   0.696133              0.003942            0.001648
# std                    0.322099              0.045568            0.024114
# min                    0.000000              0.000000            0.000000
# 25%                    0.426034              0.000000            0.000000
# 50%                    0.794423              0.000000            0.000000
# 75%                    1.000000              0.000000            0.000000
# max                    1.000000              1.000000            1.000000
#
#        app_emp_type  sum_tran_clo_tendency3m  ldeal_tenor_max  ldeal_yqz_chrg  \
# count         67362            114898.000000      8001.000000    1.241000e+03
# unique            4                      NaN              NaN             NaN
# top         PRIVATE                      NaN              NaN             NaN
# freq          59087                      NaN              NaN             NaN
# mean            NaN                 0.697152        22.366329    5.201209e-03
# std             NaN                 0.322353        17.480072    8.383158e-03
# min             NaN                 0.000000         0.000000    3.090000e-08
# 25%             NaN                 0.423332        10.000000    2.144640e-04
# 50%             NaN                 0.795943        18.000000    1.632557e-03
# 75%             NaN                 1.000000        36.000000    6.617464e-03
# max             NaN                 1.000000       242.000000    8.118109e-02
#
#         cr_prod_cnt_ccfp  deal_yqz_ir_max  ldeal_yqz_com  deal_yqz_ir_min  \
# count      355190.000000      8001.000000   1.240000e+03      8001.000000
# unique               NaN              NaN            NaN              NaN
# top                  NaN              NaN            NaN              NaN
# freq                 NaN              NaN            NaN              NaN
# mean            0.004944        26.303878   7.236572e-02        25.594477
# std             0.076439        14.746450   1.060170e-01        14.261929
# min             0.000000         6.000000   1.050000e-07         6.000000
# 25%             0.000000        17.490000   7.633601e-03        17.000000
# 50%             0.000000        23.000000   1.725998e-02        22.990000
# 75%             0.000000        29.980000   1.666667e-01        29.000000
# max             4.000000        94.000000   1.000000e+00        94.000000
#
#         cnt_tran_clo_tendency3m  rest_dynamic_cur_1m  rest_avg_paym  \
# count             114898.000000        355190.000000   3.551900e+05
# unique                      NaN                  NaN            NaN
# top                         NaN                  NaN            NaN
# freq                        NaN                  NaN            NaN
# mean                   0.699966             0.212339   7.108816e+03
# std                    0.289665             0.236098   4.716785e+04
# min                    0.019608             0.000000   0.000000e+00
# 25%                    0.500000             0.063104   0.000000e+00
# 50%                    0.714286             0.148145   0.000000e+00
# 75%                    1.000000             0.251909   0.000000e+00
# max                    1.000000             1.000000   5.798600e+06
#
#         ldeal_tenor_min  ldeal_amt_month app_comp_type  \
# count       8001.000000     1.888000e+03         67362
# unique              NaN              NaN             4
# top                 NaN              NaN       PRIVATE
# freq                NaN              NaN         59087
# mean          15.799525     1.943955e+05           NaN
# std           13.148424     4.756130e+05           NaN
# min            0.000000     0.000000e+00           NaN
# 25%            6.000000     0.000000e+00           NaN
# 50%           12.000000     8.652930e+03           NaN
# 75%           24.000000     1.783117e+05           NaN
# max          182.000000     5.579639e+06           NaN
#
#         ldeal_grace_days_pct_med  rest_dynamic_cur_3m  \
# count              355190.000000        355190.000000
# unique                       NaN                  NaN
# top                          NaN                  NaN
# freq                         NaN                  NaN
# mean                    0.001809             0.498813
# std                     0.039279             0.299354
# min                     0.000000             0.000000
# 25%                     0.000000             0.317004
# 50%                     0.000000             0.492649
# 75%                     0.000000             0.690929
# max                     1.000000             1.000000
#
#         cnt_tran_sup_tendency3m  turnover_dynamic_cur_1m  \
# count             198718.000000            355190.000000
# unique                      NaN                      NaN
# top                         NaN                      NaN
# freq                        NaN                      NaN
# mean                   0.642714                 0.204254
# std                    0.267432                 0.254973
# min                    0.008696                 0.000000
# 25%                    0.448276                 0.014579
# 50%                    0.606742                 0.127528
# 75%                    0.956522                 0.255788
# max                    1.000000                 1.000000
#
#         rest_dynamic_paym_3m  sum_tran_sup_tendency3m  rest_dynamic_il_3m  \
# count          355190.000000            198718.000000       355190.000000
# unique                   NaN                      NaN                 NaN
# top                      NaN                      NaN                 NaN
# freq                     NaN                      NaN                 NaN
# mean                0.076570                 0.627334            0.005650
# std                 0.204059                 0.294924            0.056637
# min                 0.000000                 0.000000            0.000000
# 25%                 0.000000                 0.402697            0.000000
# 50%                 0.000000                 0.604691            0.000000
# 75%                 0.000000                 0.985950            0.000000
# max                 1.000000                 1.000000            1.000000
#
#         cnt_tran_atm_tendency3m  cnt_tran_atm_tendency1m  \
# count             255595.000000            205874.000000
# unique                      NaN                      NaN
# top                         NaN                      NaN
# freq                        NaN                      NaN
# mean                   0.628063                 0.327222
# std                    0.263095                 0.274738
# min                    0.005525                 0.003171
# 25%                    0.433333                 0.142857
# 50%                    0.588235                 0.227273
# 75%                    0.888889                 0.400000
# max                    1.000000                 1.000000
#
#         turnover_dynamic_il_3m  sum_tran_atm_tendency3m  \
# count            355190.000000            255595.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                  0.003976                 0.617506
# std                   0.052736                 0.302799
# min                   0.000000                 0.000021
# 25%                   0.000000                 0.391190
# 50%                   0.000000                 0.599272
# 75%                   0.000000                 0.967010
# max                   1.000000                 1.000000
#
#         deal_grace_days_acc_s1x1  avg_pct_month_to_pclose  deal_ywz_ir_min  \
# count               70449.000000              1628.000000     95713.000000
# unique                       NaN                      NaN              NaN
# top                          NaN                      NaN              NaN
# freq                         NaN                      NaN              NaN
# mean                    0.028795                -2.673593        37.204468
# std                     0.145742                 4.516854        12.446143
# min                     0.000000               -33.623656         0.000000
# 25%                     0.000000                -3.227529        25.990000
# 50%                     0.000000                -0.941628        45.000000
# 75%                     0.000000                -0.214083        45.000000
# max                     4.379252                 0.995520        59.900000
#
#         sum_tran_sup_tendency1m  deal_ywz_ir_max  sum_tran_atm_tendency1m  \
# count             155995.000000     95713.000000            205874.000000
# unique                      NaN              NaN                      NaN
# top                         NaN              NaN                      NaN
# freq                        NaN              NaN                      NaN
# mean                   0.327835        39.498242                 0.322222
# std                    0.301340        10.503900                 0.306137
# min                    0.000000         0.000000                 0.000006
# 25%                    0.111740        45.000000                 0.100436
# 50%                    0.212212        45.000000                 0.203741
# 75%                    0.440708        45.000000                 0.440194
# max                    1.000000        59.900000                 1.000000
#
#         rest_dynamic_paym_1m  cnt_tran_sup_tendency1m  \
# count          355190.000000            155995.000000
# unique                   NaN                      NaN
# top                      NaN                      NaN
# freq                     NaN                      NaN
# mean                0.027683                 0.340662
# std                 0.097298                 0.281280
# min                 0.000000                 0.004255
# 25%                 0.000000                 0.142857
# 50%                 0.000000                 0.239130
# 75%                 0.000000                 0.444444
# max                 1.000000                 1.000000
#
#         deal_grace_days_acc_avg  turnover_dynamic_cur_3m    pack  \
# count              69433.000000            355190.000000  355190
# unique                      NaN                      NaN      12
# top                         NaN                      NaN     102
# freq                        NaN                      NaN  116986
# mean                   0.024472                 0.484825     NaN
# std                    0.140826                 0.331606     NaN
# min                    0.000000                 0.000000     NaN
# 25%                    0.000000                 0.218582     NaN
# 50%                    0.000000                 0.494372     NaN
# 75%                    0.000000                 0.726874     NaN
# max                    4.535714                 1.000000     NaN
#
#         max_pclose_date  ldeal_yqz_pc  clnt_setup_tenor  \
# count       1881.000000  2.808000e+03     355190.000000
# unique              NaN           NaN               NaN
# top                 NaN           NaN               NaN
# freq                NaN           NaN               NaN
# mean         -21.320917  2.397792e-02          4.377001
# std           28.965629  4.731026e-02          2.936530
# min         -103.354839  9.320000e-08          0.345592
# 25%          -33.451613  6.047222e-03          1.781187
# 50%          -10.161290  1.674490e-02          3.894098
# 75%           -3.612903  3.315440e-02          6.555388
# max          112.193548  1.287601e+00         13.748937
#
#         deal_grace_days_acc_max  turnover_dynamic_paym_3m  \
# count              69433.000000             355190.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                   0.029233                  0.071906
# std                    0.175279                  0.206863
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                    9.071429                  1.000000
#
#         ldeal_delinq_per_maxyqz  turnover_dynamic_paym_1m  clnt_salary_value  \
# count               8001.000000             355190.000000         712.000000
# unique                      NaN                       NaN                NaN
# top                         NaN                       NaN                NaN
# freq                        NaN                       NaN                NaN
# mean                   0.195601                  0.025108       37060.533806
# std                    0.386715                  0.104482       55084.111834
# min                    0.000000                  0.000000           0.750000
# 25%                    0.000000                  0.000000       10178.715000
# 50%                    0.000000                  0.000000       19396.330000
# 75%                    0.000000                  0.000000       39234.500000
# max                    1.000000                  1.000000      487300.000000
#
#         trans_amount_tendency3m  med_debt_prc_yqz  trans_cnt_tendency3m  \
# count             303194.000000       8001.000000         303194.000000
# unique                      NaN               NaN                   NaN
# top                         NaN               NaN                   NaN
# freq                        NaN               NaN                   NaN
# mean                   0.582237          0.920760              0.597247
# std                    0.282157          0.264637              0.247131
# min                    0.000000          0.000000              0.005747
# 25%                    0.383673          1.000000              0.428571
# 50%                    0.552169          1.000000              0.558824
# 75%                    0.820226          1.000000              0.766225
# max                    1.000000          1.000000              1.000000
#
#         ldeal_used_amt_avg_yqz  rest_dynamic_cc_1m  ldeal_used_amt_avg_ywz  \
# count              8001.000000       355190.000000            95713.000000
# unique                     NaN                 NaN                     NaN
# top                        NaN                 NaN                     NaN
# freq                       NaN                 NaN                     NaN
# mean                  0.432061            0.002191                0.901000
# std                   0.322284            0.026360                0.296082
# min                   0.000000            0.000000                0.000000
# 25%                   0.133742            0.000000                1.000000
# 50%                   0.365802            0.000000                1.000000
# 75%                   0.720972            0.000000                1.000000
# max                   1.000000            1.000000                1.000000
#
#         turnover_dynamic_cc_1m  avg_pct_debt_to_deal_amt  \
# count            355190.000000               1888.000000
# unique                     NaN                       NaN
# top                        NaN                       NaN
# freq                       NaN                       NaN
# mean                  0.000883                  0.322192
# std                   0.027321                  0.363298
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.089863
# 75%                   0.000000                  0.697071
# max                   1.000000                  1.226928
#
#         ldeal_act_days_acc_pct_avg  rest_dynamic_cc_3m  med_debt_prc_ywz  \
# count                 93448.000000       355190.000000      95713.000000
# unique                         NaN                 NaN               NaN
# top                            NaN                 NaN               NaN
# freq                           NaN                 NaN               NaN
# mean                      0.051419            0.007309          0.055074
# std                       0.134960            0.066681          0.215909
# min                       0.000000            0.000000          0.000000
# 25%                       0.000000            0.000000          0.000000
# 50%                       0.008822            0.000000          0.000000
# 75%                       0.033563            0.000000          0.000000
# max                       1.000000            1.000000          1.000000
#
#         ldeal_act_days_pct_tr3  ldeal_act_days_pct_aavg  \
# count             93448.000000             98175.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                  0.025707                 0.049943
# std                   0.115732                 0.185830
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000
#
#         ldeal_delinq_per_maxywz  turnover_dynamic_cc_3m  \
# count              95713.000000           355190.000000
# unique                      NaN                     NaN
# top                         NaN                     NaN
# freq                        NaN                     NaN
# mean                   0.009252                0.004309
# std                    0.092789                0.059852
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                0.000000
# 75%                    0.000000                0.000000
# max                    1.000000                1.000000
#
#         ldeal_act_days_pct_tr  ldeal_act_days_pct_tr4  \
# count            93448.000000            93448.000000
# unique                    NaN                     NaN
# top                       NaN                     NaN
# freq                      NaN                     NaN
# mean                 0.013938                0.013938
# std                  0.097099                0.097099
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max                  1.000000                1.000000
#
#         ldeal_act_days_pct_curr         target
# count              93448.000000  355190.000000
# unique                      NaN            NaN
# top                         NaN            NaN
# freq                        NaN            NaN
# mean                   0.013938       0.081435
# std                    0.097099       0.273503
# min                    0.000000       0.000000
# 25%                    0.000000       0.000000
# 50%                    0.000000       0.000000
# 75%                    0.000000       0.000000
# max                    1.000000       1.000000

# %% [markdown]
# Notice that the prc_accepts_a_tk have values nan and 0.

# %%
df['prc_accepts_a_tk'].unique()
# Out:
# array([nan,  0.])

# %% [markdown]
# >Now, let's create a quick function to get the column names of those with values as "nan" and "0."

# %%
# Identify the columns with only nan and zero values

def get_zero_and_nan_columns(df):
    zero_and_nan_columns = []
    for col in df.columns:
        if df[col].nunique() == 1:
            zero_and_nan_columns.append(col)
    return zero_and_nan_columns

zero_and_nan_columns = get_zero_and_nan_columns(df)
zero_and_nan_columns
# Out:
# ['prc_accepts_a_email_link',
#  'prc_accepts_a_pos',
#  'prc_accepts_a_tk',
#  'prc_accepts_a_amobile',
#  'prc_accepts_tk',
#  'prc_accepts_a_mtp',
#  'cnt_accepts_tk',
#  'prc_accepts_a_atm',
#  'prc_accepts_mtp',
#  'cnt_accepts_mtp']

# %% [markdown]
# >Having 10 columns containing only "nan" and "0." can negatively impact our machine learning model. These values offer no meaningful distinction between data points, making it difficult for the model to learn patterns and relationships within your data. This can lead to poor model performance and inaccurate predictions.

# %% [markdown]
# ### 2. Dropping columns with this "nan" and "0." values.

# %%
# Dropping columns zero_and_nan_columns 
df = df.drop(columns=zero_and_nan_columns)
df.shape
# Out:
# (355190, 106)

# %% [markdown]
# >We also find two columns with values in Rusian language. Machine learning models typically struggle with non-numeric data, especially different languages.  Translating the values to English creates a common language the model can understand.

# %%
df['clnt_trust_relation'].unique()
# Out:
# array([nan, 'MOTHER', 'BROTHER', 'FRIEND', 'SISTER', 'OTHER', 'RELATIVE',
#        'DAUGHTER', 'SON', 'FATHER', 'Близкий ро', 'Друг', 'Отец',
#        'Сестра', 'Сын', 'Мать', 'Муж', 'Брат', 'мать', 'Дальний ро',
#        'Дочь', 'Жена'], dtype=object)

# %%
df['clnt_job_position'].unique()
# Out:
# array(['начальник отдела', nan, 'ГЕНЕРАЛЬНЫЙ ДИРЕКТОР', ...,
#        'Эксперт контакт Центра', 'ПРОХЛДЧИК',
#        'ХУДОЖНИК КОМПЬЮТЕРНОЙ ГРАФИКИ'], dtype=object)

# %% [markdown]
# ### 3. Translating Rusian Values
#
# After creating a dictionary with the rusian values we applied a function to translate those values:

# %%
def replace_russian_values(df, columns_to_translate, russian_to_english_dict):
  
  # Create a copy to avoid modifying the original DataFrame
  replaced_df = df.copy()

  # Replace values in specified columns
  for col in columns_to_translate:
    replaced_df[col] = replaced_df[col].replace(russian_to_english_dict)

  return replaced_df

# Russian to English dictionary (replace with your actual dictionary)
russian_to_english_dict = {
    "MOTHER": "mother",
    "BROTHER": "brother",
    "FRIEND": "friend",
    "SISTER": "sister",
    "OTHER": "other",
    "RELATIVE": "relative",
    "DAUGHTER": "daughter",
    "SON": "son",
    "FATHER": "father",
    "Близкий ро": "close ro",
    "Друг": "friend",
    "Отец": "father",
    "Сестра": "sister",
    "Сын": "son",
    "Мать": "mother",
    "Муж": "husband",
    "Брат": "brother",
    "мать": "mother",
    "Дальний ро": "far ro",
    "Дочь": "daughter",
    "Жена": "wife",
    "начальник отдела": "department head",
    "ГЕНЕРАЛЬНЫЙ ДИРЕКТОР": "ceo",
    "Эксперт контакт Центра": "expert contact center",
    "ПРОХЛДЧИК": "cool",
    "ХУДОЖНИК КОМПЬЮТЕРНОЙ ГРАФИКИ": "computer graphics artist",
    
}

# Columns to replace (replace with your actual column names)
columns_to_translate = ['clnt_trust_relation', 'clnt_job_position']

# Replace the specified columns
df = replace_russian_values(df, columns_to_translate, russian_to_english_dict)

# %% [markdown]
# >Checking the unique values in the translated columns:

# %%
df['clnt_trust_relation'].unique()
# Out:
# array([nan, 'mother', 'brother', 'friend', 'sister', 'other', 'relative',
#        'daughter', 'son', 'father', 'close ro', 'husband', 'far ro',
#        'wife'], dtype=object)

# %%
df['clnt_job_position'].unique()
# Out:
# array(['department head', nan, 'ceo', ..., 'expert contact center',
#        'cool', 'computer graphics artist'], dtype=object)

# %% [markdown]
# ### 4. Managing null values

# %%
# Counting null values

def count_nulls(df):
    for column in df.columns:
        print(f'Nulls in column {column}:', df[column].isnull().sum())
        
count_nulls(df)
# Out:
# Nulls in column id: 0
# Nulls in column cr_prod_cnt_il: 0
# Nulls in column amount_rub_clo_prc: 38323
# Nulls in column app_registr_rgn_code: 294640
# Nulls in column turnover_dynamic_il_1m: 0
# Nulls in column cnt_tran_aut_tendency1m: 278078
# Nulls in column sum_tran_aut_tendency1m: 278078
# Nulls in column amount_rub_sup_prc: 38323
# Nulls in column sum_tran_aut_tendency3m: 244138
# Nulls in column clnt_trust_relation: 285769
# Nulls in column rest_dynamic_fdep_1m: 0
# Nulls in column cnt_tran_aut_tendency3m: 244138
# Nulls in column app_marital_status: 286956
# Nulls in column rest_dynamic_save_3m: 0
# Nulls in column cr_prod_cnt_vcu: 0
# Nulls in column rest_avg_cur: 0
# Nulls in column cnt_tran_med_tendency1m: 286223
# Nulls in column app_kind_of_prop_habitation: 295829
# Nulls in column clnt_job_position_type: 310409
# Nulls in column amount_rub_nas_prc: 38323
# Nulls in column clnt_job_position: 144379
# Nulls in column app_driving_license: 297933
# Nulls in column trans_count_sup_prc: 38323
# Nulls in column app_education: 287086
# Nulls in column cnt_tran_clo_tendency1m: 288894
# Nulls in column sum_tran_med_tendency1m: 286223
# Nulls in column trans_count_nas_prc: 38323
# Nulls in column app_travel_pass: 297933
# Nulls in column cr_prod_cnt_tovr: 0
# Nulls in column app_car: 297934
# Nulls in column cr_prod_cnt_pil: 0
# Nulls in column sum_tran_clo_tendency1m: 288894
# Nulls in column app_position_type: 294645
# Nulls in column turnover_cc: 0
# Nulls in column trans_count_atm_prc: 38323
# Nulls in column amount_rub_atm_prc: 38323
# Nulls in column turnover_paym: 0
# Nulls in column age: 0
# Nulls in column cnt_tran_med_tendency3m: 239313
# Nulls in column cr_prod_cnt_cc: 0
# Nulls in column sum_tran_med_tendency3m: 239313
# Nulls in column rest_dynamic_fdep_3m: 0
# Nulls in column rest_dynamic_il_1m: 0
# Nulls in column app_emp_type: 287828
# Nulls in column sum_tran_clo_tendency3m: 240292
# Nulls in column ldeal_tenor_max: 347189
# Nulls in column ldeal_yqz_chrg: 353949
# Nulls in column cr_prod_cnt_ccfp: 0
# Nulls in column deal_yqz_ir_max: 347189
# Nulls in column ldeal_yqz_com: 353950
# Nulls in column deal_yqz_ir_min: 347189
# Nulls in column cnt_tran_clo_tendency3m: 240292
# Nulls in column rest_dynamic_cur_1m: 0
# Nulls in column rest_avg_paym: 0
# Nulls in column ldeal_tenor_min: 347189
# Nulls in column ldeal_amt_month: 353302
# Nulls in column app_comp_type: 287828
# Nulls in column ldeal_grace_days_pct_med: 0
# Nulls in column rest_dynamic_cur_3m: 0
# Nulls in column cnt_tran_sup_tendency3m: 156472
# Nulls in column turnover_dynamic_cur_1m: 0
# Nulls in column rest_dynamic_paym_3m: 0
# Nulls in column sum_tran_sup_tendency3m: 156472
# Nulls in column rest_dynamic_il_3m: 0
# Nulls in column cnt_tran_atm_tendency3m: 99595
# Nulls in column cnt_tran_atm_tendency1m: 149316
# Nulls in column turnover_dynamic_il_3m: 0
# Nulls in column sum_tran_atm_tendency3m: 99595
# Nulls in column deal_grace_days_acc_s1x1: 284741
# Nulls in column avg_pct_month_to_pclose: 353562
# Nulls in column deal_ywz_ir_min: 259477
# Nulls in column sum_tran_sup_tendency1m: 199195
# Nulls in column deal_ywz_ir_max: 259477
# Nulls in column sum_tran_atm_tendency1m: 149316
# Nulls in column rest_dynamic_paym_1m: 0
# Nulls in column cnt_tran_sup_tendency1m: 199195
# Nulls in column deal_grace_days_acc_avg: 285757
# Nulls in column turnover_dynamic_cur_3m: 0
# Nulls in column pack: 0
# Nulls in column max_pclose_date: 353309
# Nulls in column ldeal_yqz_pc: 352382
# Nulls in column clnt_setup_tenor: 0
# Nulls in column deal_grace_days_acc_max: 285757
# Nulls in column turnover_dynamic_paym_3m: 0
# Nulls in column ldeal_delinq_per_maxyqz: 347189
# Nulls in column turnover_dynamic_paym_1m: 0
# Nulls in column clnt_salary_value: 354478
# Nulls in column trans_amount_tendency3m: 51996
# Nulls in column med_debt_prc_yqz: 347189
# Nulls in column trans_cnt_tendency3m: 51996
# Nulls in column ldeal_used_amt_avg_yqz: 347189
# Nulls in column rest_dynamic_cc_1m: 0
# Nulls in column ldeal_used_amt_avg_ywz: 259477
# Nulls in column turnover_dynamic_cc_1m: 0
# Nulls in column avg_pct_debt_to_deal_amt: 353302
# Nulls in column ldeal_act_days_acc_pct_avg: 261742
# Nulls in column rest_dynamic_cc_3m: 0
# Nulls in column med_debt_prc_ywz: 259477
# Nulls in column ldeal_act_days_pct_tr3: 261742
# Nulls in column ldeal_act_days_pct_aavg: 257015
# Nulls in column ldeal_delinq_per_maxywz: 259477
# Nulls in column turnover_dynamic_cc_3m: 0
# Nulls in column ldeal_act_days_pct_tr: 261742
# Nulls in column ldeal_act_days_pct_tr4: 261742
# Nulls in column ldeal_act_days_pct_curr: 261742
# Nulls in column target: 0

# %% [markdown]
# >We've identified several columns with potentially high numbers of missing values. To assess their relevance, let's calculate the percentage of null values in each column and sort them in descending order. This will reveal which columns have the most missing data.

# %%
def get_null_value_counts(df):
  
  null_counts = df.isna().sum()
  null_counts_df = pd.DataFrame({'column_name': null_counts.index, 'null_count': null_counts.values})
  
  return null_counts_df

# Get null value counts
null_counts_df = get_null_value_counts(df)
null_counts_df = null_counts_df.sort_values(by='null_count', ascending=False)
null_counts_df['pcnt_null'] = null_counts_df['null_count'] / df.shape[0]

# %%
null_counts_df.head(10)
# Out:
#                  column_name  null_count  pcnt_null
# 86         clnt_salary_value      354478   0.997995
# 49             ldeal_yqz_com      353950   0.996509
# 46            ldeal_yqz_chrg      353949   0.996506
# 69   avg_pct_month_to_pclose      353562   0.995417
# 79           max_pclose_date      353309   0.994704
# 94  avg_pct_debt_to_deal_amt      353302   0.994685
# 55           ldeal_amt_month      353302   0.994685
# 80              ldeal_yqz_pc      352382   0.992094
# 45           ldeal_tenor_max      347189   0.977474
# 50           deal_yqz_ir_min      347189   0.977474

# %% [markdown]
# > Our initial analysis revealed 72 columns with a significant amount of missing data, hovering around 30% null values. To improve data quality and model performance, we'll focus on removing columns with extreme levels of missingness. We'll establish a threshold of 70% null values. Any column exceeding this threshold will be dropped from the dataset. This approach ensures we retain columns with a reasonable amount of data for analysis while eliminating those unlikely to contribute meaningfully due to excessive missing information.

# %%
def drop_irrelevant_columns(df, null_value_threshold=50000):
 
  null_counts = df.isnull().sum()
  columns_to_drop = null_counts[null_counts > null_value_threshold].index.tolist()
  return df.drop(columns_to_drop, axis=1)


df = drop_irrelevant_columns(df)
df.shape
# Out:
# (355190, 42)

# %%
null_counts_df.head(12)
# Out:
#                  column_name  null_count  pcnt_null
# 86         clnt_salary_value      354478   0.997995
# 49             ldeal_yqz_com      353950   0.996509
# 46            ldeal_yqz_chrg      353949   0.996506
# 69   avg_pct_month_to_pclose      353562   0.995417
# 79           max_pclose_date      353309   0.994704
# 94  avg_pct_debt_to_deal_amt      353302   0.994685
# 55           ldeal_amt_month      353302   0.994685
# 80              ldeal_yqz_pc      352382   0.992094
# 45           ldeal_tenor_max      347189   0.977474
# 50           deal_yqz_ir_min      347189   0.977474
# 90    ldeal_used_amt_avg_yqz      347189   0.977474
# 54           ldeal_tenor_min      347189   0.977474

# %% [markdown]
# Notice that we still have 46 remaining columns where 11 still have missing values. After doing a research we found this columns could be important for the model. For instance:
#
# >The column named "The fraction of transactions with MCC to the whole amount of the transaction in the period (rub)" captures the proportion of your clients' total spending (in rubles) that involved transactions with a Merchant Category Code (MCC) during a specific timeframe.
#
# >Client Spending Habits and Risk:
#
# 1. **High MCC Transaction Fraction:** A high value in this column could indicate clients who frequently use their cards for purchases categorized by MCCs (e.g., groceries, travel, entertainment). Analyzing spending patterns within these categories might reveal:
#
# * Clients Reliant on Specific Categories: If a client relies heavily on MCC transactions for essential categories (groceries, utilities), a disruption in their preferred merchants or spending limitations might lead to churn.
# * Clients Prone to Impulse Purchases: If a client has a high MCC transaction fraction in categories associated with impulse buying (entertainment, dining), they might be more susceptible to churn if offered better deals elsewhere.
#
# 2. **Low MCC Transaction Fraction:** A low value could suggest clients who:
#
# * Prefer Cash or Alternative Payments: They might rely more on cash or alternative payment methods for everyday purchases. Churn might be less likely due to a lack of dependence on the specific card.
# *Use Card for Large Transactions: They might primarily use their cards for larger, less frequent purchases (not categorized by MCC) like electronics or travel bookings. Churn might depend on factors beyond everyday spending habits.
#
#
# > Based on this, the decision here is to drop the rows with missing values which represents a 10% of the total data.

# %%
# drop rowns with null values from the dataframe df
df = df.dropna()
df.shape
# Out:
# (316867, 42)

# %% [markdown]
# ### 5. Checking datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316867 entries, 0 to 355189
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        316867 non-null  int64
#  1   cr_prod_cnt_il            316867 non-null  int64
#  2   amount_rub_clo_prc        316867 non-null  float64
#  3   turnover_dynamic_il_1m    316867 non-null  float64
#  4   amount_rub_sup_prc        316867 non-null  float64
#  5   rest_dynamic_fdep_1m      316867 non-null  float64
#  6   rest_dynamic_save_3m      316867 non-null  float64
#  7   cr_prod_cnt_vcu           316867 non-null  int64
#  8   rest_avg_cur              316867 non-null  float64
#  9   amount_rub_nas_prc        316867 non-null  float64
#  10  trans_count_sup_prc       316867 non-null  float64
#  11  trans_count_nas_prc       316867 non-null  float64
#  12  cr_prod_cnt_tovr          316867 non-null  int64
#  13  cr_prod_cnt_pil           316867 non-null  int64
#  14  turnover_cc               316867 non-null  float64
#  15  trans_count_atm_prc       316867 non-null  float64
#  16  amount_rub_atm_prc        316867 non-null  float64
#  17  turnover_paym             316867 non-null  float64
#  18  age                       316867 non-null  int64
#  19  cr_prod_cnt_cc            316867 non-null  int64
#  20  rest_dynamic_fdep_3m      316867 non-null  float64
#  21  rest_dynamic_il_1m        316867 non-null  float64
#  22  cr_prod_cnt_ccfp          316867 non-null  int64
#  23  rest_dynamic_cur_1m       316867 non-null  float64
#  24  rest_avg_paym             316867 non-null  float64
#  25  ldeal_grace_days_pct_med  316867 non-null  float64
#  26  rest_dynamic_cur_3m       316867 non-null  float64
#  27  turnover_dynamic_cur_1m   316867 non-null  float64
#  28  rest_dynamic_paym_3m      316867 non-null  float64
#  29  rest_dynamic_il_3m        316867 non-null  float64
#  30  turnover_dynamic_il_3m    316867 non-null  float64
#  31  rest_dynamic_paym_1m      316867 non-null  float64
#  32  turnover_dynamic_cur_3m   316867 non-null  float64
#  33  pack                      316867 non-null  object
#  34  clnt_setup_tenor          316867 non-null  float64
#  35  turnover_dynamic_paym_3m  316867 non-null  float64
#  36  turnover_dynamic_paym_1m  316867 non-null  float64
#  37  rest_dynamic_cc_1m        316867 non-null  float64
#  38  turnover_dynamic_cc_1m    316867 non-null  float64
#  39  rest_dynamic_cc_3m        316867 non-null  float64
#  40  turnover_dynamic_cc_3m    316867 non-null  float64
#  41  target                    316867 non-null  int64
# dtypes: float64(32), int64(9), object(1)
# memory usage: 104.0+ MB

# %% [markdown]
# >There are no visible problems with the datatypes

# %% [markdown]
# ### 6. Removing duplicated values

# %%
# removing duplicates
df = df.drop_duplicates()
df.shape
# Out:
# (316867, 42)

# %% [markdown]
# ### 7. Checking outliers

# %% [markdown]
# Send DataFrame to Target Folder in S3

# %%
# Convert the DataFrame to a CSV string
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)

# %%
# Upload the new CSV to the desired folder in the S3 bucket
s3_client.put_object(Bucket=bucket_name, Key=output_file_key, Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'AZ238F7A8HAZMKMJ',
#   'HostId': 'pNAmxV1Ts/EUkUASCP9rO7SwXfjzKgcpF9oYxwYChry5zh13hs+3cDA+HGPy8vEEYrwsUnmTtwc=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'pNAmxV1Ts/EUkUASCP9rO7SwXfjzKgcpF9oYxwYChry5zh13hs+3cDA+HGPy8vEEYrwsUnmTtwc=',
#    'x-amz-request-id': 'AZ238F7A8HAZMKMJ',
#    'date': 'Sun, 17 Mar 2024 13:59:03 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"0861a46d8ccf7388d8fe3bd7d3e1da82"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"0861a46d8ccf7388d8fe3bd7d3e1da82"',
#  'ServerSideEncryption': 'AES256'}
